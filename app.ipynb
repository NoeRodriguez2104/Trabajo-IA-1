# %%
# --- Celda 1: Instalaciones ---
# Instalamos Gradio (interfaz web), sentence-transformers (embeddings),
# faiss-cpu (búsqueda vectorial) y la librería de Google (para Gemini).
# --- Celda 1: Instalaciones ---
print("Instalando librerías...")
# !pip install gradio sentence-transformers faiss-cpu google-generativeai python-dotenv --quiet
print("✅ Librerías instaladas.")
# Out:
# Instalando librerías...
# ✅ Librerías instaladas.

# %%
# --- Celda 2: Importaciones ---
import gradio as gr
import json
import numpy as np
import faiss
from pathlib import Path
from sentence_transformers import SentenceTransformer
import google.generativeai as genai
import os                       # 👈 Importante para dotenv
from dotenv import load_dotenv  # 👈 Importamos la función
print("✅ Librerías importadas.")
# Out:
# ✅ Librerías importadas.

# %%
# --- Celda 3: Configuración y API Key (con DotEnv) ---

# 1. Cargar las variables del archivo .env a la memoria del sistema
load_dotenv()

# 2. Leer la API key desde las variables de entorno
API_KEY = os.getenv("GEMINI_API_KEY")

if not API_KEY:
    print("🛑 ¡ERROR! No se encontró 'GEMINI_API_KEY'.")
    print("Asegúrate de haber creado el archivo .env y puesto la clave allí.")
else:
    try:
        genai.configure(api_key=API_KEY)
        print("✅ API Key de Gemini cargada de forma segura desde .env.")
    except Exception as e:
        print(f"🛑 Error configurando la API Key: {e}")

# Nombres de archivos y modelos
DATA_FILE = "music_faiss_map_with_embeddings.json"
EMBED_MODEL = "all-MiniLM-L6-v2"
GEMINI_MODEL = "models/gemini-2.5-flash"
# Out:
# ✅ API Key de Gemini cargada de forma segura desde .env.

# %%
# --- Celda 4: Cargar Datos y Construir el "Cerebro" (FAISS) ---

p = Path(DATA_FILE)
if not p.exists():
    print(f"❌ ERROR: No se encontró el archivo '{DATA_FILE}'.")
    print("Por favor, sube tu archivo JSON al panel de Archivos (a la izquierda).")
else:
    print(f"Cargando datos desde {DATA_FILE}...")
    data = json.loads(p.read_text(encoding="utf-8"))
    metas = data["metadatas"]
    print(f"✅ Canciones cargadas: {len(metas)}")

    # Cargar el modelo de embeddings
    print(f"Cargando modelo de embeddings '{EMBED_MODEL}'...")
    model = SentenceTransformer(EMBED_MODEL)

    # Extraer embeddings y doc_ids para FAISS
    embeddings = []
    doc_ids = []
    for doc_id, meta in metas.items():
        emb = meta.get("embedding")
        if emb:
            embeddings.append(np.array(emb, dtype=np.float32))
            doc_ids.append(doc_id)

    # Construir el índice FAISS
    emb_matrix = np.vstack(embeddings)
    faiss.normalize_L2(emb_matrix) # Normalizar para usar producto interno (IP)

    dim = emb_matrix.shape[1]
    index = faiss.IndexFlatIP(dim) # IP = Inner Product (producto escalar)
    index.add(emb_matrix)

    print(f"✅ Índice FAISS (el 'cerebro' de búsqueda) creado con {index.ntotal} canciones.")
# Out:
# Cargando datos desde music_faiss_map_with_embeddings.json...
# ✅ Canciones cargadas: 50
# Cargando modelo de embeddings 'all-MiniLM-L6-v2'...
# ✅ Índice FAISS (el 'cerebro' de búsqueda) creado con 50 canciones.

# %%
# --- Celda 5: Funciones del RAG (Las "Herramientas") ---

def embed_query(query):
    """Convierte una consulta de texto en un vector embedding."""
    return model.encode([query], convert_to_numpy=True)[0]

def retrieve_similar(query_emb, k=4):
    """Busca en FAISS los k documentos más similares."""
    q = np.asarray(query_emb, dtype=np.float32).reshape(1, -1)
    faiss.normalize_L2(q)
    
    D, I = index.search(q, k) # D=Distancias (scores), I=Índices
    
    results = []
    for score, idx in zip(D[0], I[0]):
        song_id = doc_ids[idx]
        meta = metas[song_id]
        results.append({
            "doc_id": song_id,
            "score": float(score),
            "meta": meta
        })
    return results

def build_rag_prompt(query, retrieved_docs):
    """Construye el prompt para Gemini con el contexto encontrado."""
    context = ""
    for i, doc in enumerate(retrieved_docs):
        meta = doc["meta"]
        metadata_dict = meta.get('metadata', {})
        context += f"""
[Documento {i+1}]
Título: {meta.get('title', 'N/A')}
Artista: {meta.get('artist', 'N/A')}
Año: {metadata_dict.get('released', 'N/A')}
Género: {metadata_dict.get('genre', 'N/A')}
"""
    
    prompt = f"""
Eres un asistente experto en música llamado 'Discogs RAG'.
Tu tarea es responder la pregunta del usuario basándote *únicamente* en el contexto proporcionado.
Si la respuesta no está en el contexto, di "No encontré información sobre eso en mi base de datos".

---
[CONTEXTO]
{context.strip()}
---

[PREGUNTA DEL USUARIO]
{query}

[TU RESPUESTA]
"""
    return prompt

def call_gemini(prompt_text):
    """Llama a la API de Gemini para generar una respuesta."""
    try:
        model_obj = genai.GenerativeModel(GEMINI_MODEL)
        response = model_obj.generate_content(prompt_text)
        return response.text
    except Exception as e:
        print(f"Error al llamar a Gemini: {e}")
        return "Hubo un error al contactar al modelo de IA. Por favor, revisa tu API Key."

print("✅ Funciones RAG (embed, retrieve, build, call) definidas.")
# Out:
# ✅ Funciones RAG (embed, retrieve, build, call) definidas.

# %%
# --- Celda 6: Función Principal (El "Orquestador") ---

def responder_pregunta_rag(pregunta_usuario, historial_chat):
    """
    Esta es la función principal que Gradio llamará.
    Recibe la pregunta y el historial, y devuelve la respuesta.
    """
    if not pregunta_usuario.strip():
        return "Por favor, hazme una pregunta."

    print(f"\nPregunta recibida: '{pregunta_usuario}'")
    
    # Paso 1: Embed (Convertir pregunta a vector)
    q_emb = embed_query(pregunta_usuario)
    
    # Paso 2: Retrieve (Buscar en FAISS)
    retrieved_docs = retrieve_similar(q_emb, k=50)
    
    # Paso 3: Build Prompt (Construir prompt con contexto)
    prompt = build_rag_prompt(pregunta_usuario, retrieved_docs)
    print(f"Prompt construido para Gemini:\n{prompt}\n")
    
    # Paso 4: Generate (Llamar a Gemini)
    respuesta = call_gemini(prompt)
    
    print(f"Respuesta generada: '{respuesta}'")
    return respuesta

print("✅ Función 'orquestadora' de Gradio definida.")
# Out:
# ✅ Función 'orquestadora' de Gradio definida.

# %%
# --- Celda 7: ¡Lanzar la Interfaz (Gradio)! ---

print("🚀 Lanzando interfaz de Gradio...")

iface = gr.ChatInterface(
    fn=responder_pregunta_rag,
    title="🎵 Experto Musical (RAG + Discogs)",
    description="Hazme una pregunta sobre la base de datos de música. Usaré RAG para encontrar la respuesta.",
    examples=[
        "¿Qué discos tiene jazz?", 
        "Recomiéndame vinilos de rock europeo", 
        "Canciones de rock clásico con guitarras"
    ],
    theme="soft"
)

# .launch(share=True) crea un enlace público temporal (72h)
# para que puedas probarlo en tu navegador o teléfono.
iface.launch(debug=True, share=True)
# Out:
# 🚀 Lanzando interfaz de Gradio...
# c:\Users\bryan\Desktop\proyectosClase\Trabajo-IA-1\env_bryan\Lib\site-packages\gradio\chat_interface.py:347: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   self.chatbot = Chatbot(
# * Running on local URL:  http://127.0.0.1:7860
#
# Could not create share link. Missing file: C:\Users\bryan\.cache\huggingface\gradio\frpc\frpc_windows_amd64_v0.3.
#
# Please check your internet connection. This can happen if your antivirus software blocks the download of this file. You can install manually by following these steps:
#
# 1. Download this file: https://cdn-media.huggingface.co/frpc-gradio-0.3/frpc_windows_amd64.exe
# 2. Rename the downloaded file to: frpc_windows_amd64_v0.3
# 3. Move the file to this location: C:\Users\bryan\.cache\huggingface\gradio\frpc
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Pregunta recibida: 'musico de los años 90'
# Prompt construido para Gemini:
#
# Eres un asistente experto en música llamado 'Discogs RAG'.
# Tu tarea es responder la pregunta del usuario basándote *únicamente* en el contexto proporcionado.
# Si la respuesta no está en el contexto, di "No encontré información sobre eso en mi base de datos".
#
# ---
# [CONTEXTO]
# [Documento 1]
# Título: Love, Strings & Jobim (The Eloquence Of Antonio Carlos Jobim)
# Artista: Antonio Carlos Jobim
# Año: 1966
# Género: Jazz
#
# [Documento 2]
# Título: LAX
# Artista: The Game (2)
# Año: 2008
# Género: Hip Hop
#
# [Documento 3]
# Título: World Of Magic
# Artista: Pharao
# Año: 1995
# Género: Electronic
#
# [Documento 4]
# Título: Kinematografia
# Artista: Paktofonika
# Año: N/A
# Género: Hip Hop
#
# [Documento 5]
# Título: Ascenseur Pour L'échafaud * Des Femmes Disparaissent
# Artista: The Miles Davis Quintet & Art Blakey & The Jazz Messengers
# Año: N/A
# Género: Jazz, Stage & Screen
#
# [Documento 6]
# Título: Life 'N Perspectives Of A Genuine Crossover
# Artista: Urban Dance Squad
# Año: 2016-11-07
# Género: Hip Hop, Rock
#
# [Documento 7]
# Título: Army Of One
# Artista: The Old Firm Casuals
# Año: 2011-12-16
# Género: Rock
#
# [Documento 8]
# Título: Love Insane / Keep Me Real
# Artista: Craggz & Parallel Forces
# Año: 2005-09-00
# Género: Electronic
#
# [Documento 9]
# Título: Cannis b/w Mbukinya
# Artista: Duma (6)
# Año: 2021-05-28
# Género: Electronic, Rock
#
# [Documento 10]
# Título: U.D.S. Hollywood Live / Pinkpop Live
# Artista: Urban Dance Squad
# Año: 1990
# Género: Rock
#
# [Documento 11]
# Título: Hup
# Artista: The Wonder Stuff
# Año: 1989
# Género: Rock
#
# [Documento 12]
# Título: Bizarre Domination
# Artista: Terveet Kädet
# Año: 1992
# Género: Rock
#
# [Documento 13]
# Título: Never Turn Your Back On Mother Earth
# Artista: Sparks
# Año: 1974
# Género: Rock
#
# [Documento 14]
# Título: Does His Thing (Happy Music)
# Artista: James Last
# Año: 1970
# Género: Pop
#
# [Documento 15]
# Título: Faraway Land
# Artista: J.C. Satàn
# Año: 2012-10-05
# Género: Rock
#
# [Documento 16]
# Título: Scheisse Nicht Schon Wieder Bernstein
# Artista: Kommando Sonne-nmilch
# Año: 2008-10-10
# Género: Rock
#
# [Documento 17]
# Título: Untitled
# Artista: The Sect (2) & Sitry
# Año: 1999
# Género: Electronic
#
# [Documento 18]
# Título: The Things We Think We're Missing
# Artista: Balance And Composure
# Año: 2021-05-03
# Género: Rock
#
# [Documento 19]
# Título: Bill Evans
# Artista: Bill Evans
# Año: 1982
# Género: Jazz
#
# [Documento 20]
# Título: 45:33 Remixes By: Padded Cell, Prince Language
# Artista: LCD Soundsystem
# Año: 2009-10-02
# Género: Electronic
#
# [Documento 21]
# Título: Freak 'N' Roll ...Into The Fog - The Black Crowes, All Join Hands, The Fillmore, San Francisco
# Artista: The Black Crowes
# Año: 2006
# Género: Rock, Blues
#
# [Documento 22]
# Título: It's All Happening Now (The Ancient Series Three)
# Artista: Lewis Parker
# Año: 2002
# Género: Hip Hop
#
# [Documento 23]
# Título: Can't Get Enough
# Artista: Suede
# Año: 1999-11-08
# Género: Rock
#
# [Documento 24]
# Título: Burning At Both Ends
# Artista: Set Your Goals
# Año: 2011-06-28
# Género: Rock
#
# [Documento 25]
# Título: "My Life" (w/ Bill Frisell) b/w "Dan I Am" / "Bad Memories"
# Artista: Sheltered Workshop Singers
# Año: 2021-04-22
# Género: Rock
#
# [Documento 26]
# Título: Full Up (Bunny 'Striker' Lee's Early Reggae Productions 1968-72)
# Artista: Bunny Lee
# Año: 2014-10-28
# Género: Reggae
#
# [Documento 27]
# Título: Gehasst, Verdammt, Vergöttert
# Artista: Böhse Onkelz
# Año: 2014-03-00
# Género: Rock
#
# [Documento 28]
# Título: Strings
# Artista: Kristin Hersh
# Año: 1994-04-05
# Género: Rock
#
# [Documento 29]
# Título: Lost Reworks
# Artista: Trentemøller
# Año: 2014-09-01
# Género: Electronic, Rock, Pop
#
# [Documento 30]
# Título: The Masquerade Ball
# Artista: Axel Rudi Pell
# Año: 2000-03-28
# Género: Rock
#
# [Documento 31]
# Título: Blood Red River
# Artista: The Scientists (2)
# Año: 1984-08-00
# Género: Rock
#
# [Documento 32]
# Título: Honour Among Thieves
# Artista: Antiseen
# Año: 1988-10-00
# Género: Rock
#
# [Documento 33]
# Título: Cost Of Living
# Artista: Downtown Boys (2)
# Año: 2017-08-00
# Género: Rock
#
# [Documento 34]
# Título: My Love For Evermore
# Artista: The Hillbilly Moon Explosion & Emanuela Hutter
# Año: 2015
# Género: Rock
#
# [Documento 35]
# Título: I Love You / Somebody Tell Me My Name
# Artista: People (4)
# Año: 1968-01-00
# Género: Rock
#
# [Documento 36]
# Título: The Blues
# Artista: Pete Fountain
# Año: N/A
# Género: Jazz
#
# [Documento 37]
# Título: Glitches Brew
# Artista: Afternoon Coffee Boys
# Año: 2006-03-30
# Género: Electronic
#
# [Documento 38]
# Título: Keep On
# Artista: Nightmares On Wax
# Año: 2000-01-01
# Género: Electronic
#
# [Documento 39]
# Título: Flashlight Seasons
# Artista: Gravenhurst
# Año: 2014-12-01
# Género: Rock
#
# [Documento 40]
# Título: Volume 1
# Artista: Mystic & Fire
# Año: 1994
# Género: Electronic
#
# [Documento 41]
# Título: Something To Believe In
# Artista: Poison (3)
# Año: 1990
# Género: Rock
#
# [Documento 42]
# Título: Unusual Suspects
# Artista: Leslie West
# Año: 2011
# Género: Rock, Blues
#
# [Documento 43]
# Título: Heut' Oder Nie
# Artista: Die Walter Elf
# Año: 1987-07-00
# Género: Rock
#
# [Documento 44]
# Título: The Best Of Aretha Franklin
# Artista: Aretha Franklin
# Año: N/A
# Género: Funk / Soul
#
# [Documento 45]
# Título: Will It Go Round In Circles / Blackbird
# Artista: Billy Preston
# Año: 1972
# Género: Funk / Soul
#
# [Documento 46]
# Título: Black (Inside)
# Artista: Rolf Julius
# Año: 2011-02-00
# Género: Electronic
#
# [Documento 47]
# Título: When My Dreamboat Comes Home / Blueberry Hill
# Artista: Fats Domino
# Año: 1973
# Género: Rock, Blues
#
# [Documento 48]
# Título: Fabric 51
# Artista: DJ T.
# Año: 2010-03-00
# Género: Electronic
#
# [Documento 49]
# Título: Martha Wainwright
# Artista: Martha Wainwright
# Año: 2005
# Género: Rock, Folk, World, & Country
#
# [Documento 50]
# Título: Exposure
# Artista: Sendex
# Año: 2003-12-00
# Género: Electronic
# ---
#
# [PREGUNTA DEL USUARIO]
# musico de los años 90
#
# [TU RESPUESTA]
#
#
# Respuesta generada: 'Aquí tienes algunos músicos con lanzamientos en los años 90, según tu base de datos:
#
# *   Pharao (1995)
# *   Urban Dance Squad (1990)
# *   Terveet Kädet (1992)
# *   Mystic & Fire (1994)
# *   Kristin Hersh (1994)
# *   The Sect (2) & Sitry (1999)
# *   Poison (3) (1990)
# *   Suede (1999)'
# Keyboard interruption in main thread... closing server.
